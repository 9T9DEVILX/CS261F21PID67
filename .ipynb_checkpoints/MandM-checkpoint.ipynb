# %%
# !pip install selenium
import requests
import pandas as pd
import re
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
from selenium import webdriver

MovieTitle=[]
Rating=[]
Type=[]
Duration=[]
Year=[]
Cast=[]
Director=[]
path='C:\\chromedriver_win32\\chromedriver.exe'
driver=webdriver.Chrome(executable_path=path)
url=driver.get('https://www.imdb.com/search/title/?num_votes=1,&sort=user_rating,desc&ref_=adv_prv')

def scrapping(url):
   

    content=driver.page_source
    soup=BeautifulSoup(content)
    movies= soup.find_all('div', class_="lister-item mode-advanced")
    #print(movies)
    for movie in movies:
    
        #-----------------Title------------------------------
        title= movie.find('a')
        ok= title.find('img')
        titles= ok['alt']
        MovieTitle.append(titles)
        # print(titles)
    
    
        #-----------------Rating--------------------------
    
        r = movie.find('strong')
        if not r:
            rt='Not Availabe'
            Rating.append(rt)
        else:
            rating = movie.find('strong').text
            Rating.append(rating)
        
        
        #---------------Type/Category-------------------------
        t = movie.find('span', class_="genre")
        if not t:
            tp='Not Available'
            Type.append(tp)
        else:
            typs=movie.find('span', class_="genre")
            typs=typs.text.strip()
            Type.append(typs)
        
        
        #----------------Duration---------------------
        d = movie.find('span', class_="runtime")
        if not d:
            d='Not Available'
            Duration.append(d)
        else:
            du=movie.find('span', class_="runtime").text
            Duration.append(du)
        
        #---------------Year-----------------------
        y = movie.find('span', class_="lister-item-year text-muted unbold")
        if not y:
            yr='Not Availabe'
            Year.append(yr)
        else:
            year=movie.find('span', class_="lister-item-year text-muted unbold").text
            Year.append(year)

        #----------------Director ------------------
        dirc = movie.find('p',attrs={'class':''}).find('a')
    
        if not dirc:
            de='Not Availabe'
            
            Director.append(de)
        else:
            di=movie.find('p',attrs={'class':''}).find('a').text
           
            Director.append(di)
        
    
        #---------------Stars------------------------
        strs= movie.find('p',attrs={'class':''}).findAll('a')
        if not strs:
            ss='Not Availabe'
            Cast.append(ss)
        else:
            stt= movie.find('p',attrs={'class':''}).findAll('a')
            stt=[a.text for a in stt][1:]
            x=' '.join(stt)
        
        
            if not x:
                no='Not Availabe'
                Cast.append(no)
            
            else:
                Cast.append(x)
    driver.find_element(By.XPATH, "(//a[@class='lister-page-next next-page'])").click()
    
    #df = pd.DataFrame({'Title':MovieTitle,'Rating':Rating,'Type':Type,'Duration':Duration,'Release Year':Year,'Director':Director,'Cast/Star':Cast}) 
    #df.to_csv('MoviesAndMunchingg.csv', mode='a',index=False, header=False, encoding='utf-8')



#stroring url .......
for i in range(1,100000,50):
    print(i)
    scrapping(url)

df = pd.DataFrame({'Title':MovieTitle,'Rating':Rating,'Type':Type,'Duration':Duration,'Release Year':Year,'Director':Director,'Cast/Star':Cast}) 
df.to_csv('MoviesAndMunchingg.csv', index=False, encoding='utf-8')
# Out:
# ...
# <ipython-input-7-cdc37eaf201a>:17: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path=path)
# 1
# 51
# 101
# 151
