# %%
import requests
from bs4 import BeautifulSoup
MovieTitle=[]
Rating=[]
Type=[]
Duration=[]
Year=[]
Cast=[]
Director=[]
#stroring url .......

url=requests.get('https://www.imdb.com/search/title/?num_votes=1,&sort=user_rating,desc&start=51&ref_=adv_nxt').text
#print(url)

soup= BeautifulSoup(url, 'lxml')
movies= soup.find_all('div', class_="lister-item mode-advanced")
#print(movies)
for movie in movies:
    
    #-----------------Title------------------------------
    title= movie.find('a')
    ok= title.find('img')
    titles= ok['alt']
    MovieTitle.append(titles)
   # print(titles)
    
    
    #-----------------Rating--------------------------
    
    r = movie.find('strong')
    if not r:
        rt='Not Availabe'
        Rating.append(rt)
    else:
        rating = movie.find('strong').text
        Rating.append(rating)
        
        
    #---------------Type/Category-------------------------
    t = movie.find('span', class_="genre")
    if not t:
        tp='Not Available'
        Type.append(tp)
    else:
        typs=movie.find('span', class_="genre")
        typs=typs.text.strip()
        Type.append(typs)
        
        
    #----------------Duration---------------------
    d = movie.find('span', class_="runtime")
    if not d:
        d='Not Available'
        Duration.append(d)
    else:
        du=movie.find('span', class_="runtime").text
        Duration.append(du)
        
    #---------------Year-----------------------
    y = movie.find('span', class_="lister-item-year text-muted unbold")
    if not y:
        yr='None'
        Year.append(yr)
    else:
        year=movie.find('span', class_="lister-item-year text-muted unbold").text
        Year.append(year)

    #----------------Director ------------------
    #dirc = movie.find()
